# %% [markdown]
# ## [Link the course (Getting started with the Twitter API v2 for academic research](https://github.com/twitterdev/getting-started-with-the-twitter-api-v2-for-academic-research/blob/main/modules/6a-labs-code-academic-python.md)

# %%
#!pip install twarc

# %% [markdown]
# ## Searching for Tweets Older than the last 7 days, select interested fields, writing response to a text file

# %%
from twarc import Twarc2, expansions
import datetime
import json
import csv

# Replace your bearer token below. You may use below code if you do not have a twitter developer account yet.
# For security reason, the token only works for today's class. Please use your own token in the future.
client = Twarc2(bearer_token="AAAAAAAAAAAAAAAAAAAAAGSXZQEAAAAAk6YVv7DVW74eDZZ5u698Inv4QXc%3DCpTroI60R3imjzDPgwoEr6CRWIWjxoqSR1jOTQJtl0to45EHce")


def main():
    # Specify the start time in UTC for the time period you want replies from
    start_time = datetime.datetime(2022, 3, 20, 1, 0, 0, 0, datetime.timezone.utc)

    # Specify the end time in UTC for the time period you want Tweets from
    end_time = datetime.datetime(2022, 3, 20, 2, 0, 0, 0, datetime.timezone.utc)

    # This is where we specify our query as discussed in module 5.
    query = "(#climatechange, #globalwarming) OR (climate change) -is:retweet lang:en place:Boston"

    # The search_all method call the full-archive search endpoint to get Tweets based on the query, start and end times
    search_results = client.search_all(query=query, start_time=start_time, end_time=end_time, max_results=100)

    # Twarc returns all Tweets for the criteria set above, so we page through the results
    for page in search_results:
        # The Twitter API v2 returns the Tweet information and the user, media etc.  separately
        # so we use expansions.flatten to get all the information in a single JSON
        result = expansions.flatten(page)
        for tweet in result:
            # Here we are printing the full Tweet object JSON to the console
            print(json.dumps(tweet))

if __name__ == "__main__":
    main()
# Out:
# {"entities": {"mentions": [{"start": 0, "end": 9, "username": "tim_cook", "id": "1636590253", "profile_image_url": "https://pbs.twimg.com/profile_images/1403556543098916872/83tVAzyy_normal.jpg", "description": "Apple CEO \uf8ff Auburn \ud83c\udfc0 \ud83c\udfc8 Duke \ud83c\udfc0 National Parks \ud83c\udfde\ufe0f \u201cLife's most persistent and urgent question is, 'What are you doing for others?'\u201d - MLK. he/him", "created_at": "2013-07-31T22:41:25.000Z", "verified": true, "public_metrics": {"followers_count": 13311469, "following_count": 70, "tweet_count": 1298, "listed_count": 23656}, "name": "Tim Cook", "location": "Cupertino", "protected": false, "url": ""}, {"start": 14, "end": 23, "username": "tim_cook", "id": "1636590253", "profile_image_url": "https://pbs.twimg.com/profile_images/1403556543098916872/83tVAzyy_normal.jpg", "description": "Apple CEO \uf8ff Auburn \ud83c\udfc0 \ud83c\udfc8 Duke \ud83c\udfc0 National Parks \ud83c\udfde\ufe0f \u201cLife's most persistent and urgent question is, 'What are you doing for others?'\u201d - MLK. he/him", "created_at": "2013-07-31T22:41:25.000Z", "verified": true, "public_metrics": {"followers_count": 13311469, "following_count": 70, "tweet_count": 1298, "listed_count": 23656}, "name": "Tim Cook", "location": "Cupertino", "protected": false, "url": ""}], "hashtags": [{"start": 206, "end": 220, "tag": "globalwarming"}, {"start": 227, "end": 241, "tag": "climatechange"}], "annotations": [{"start": 40, "end": 44, "probability": 0.4013, "type": "Organization", "normalized_text": "Apple"}, {"start": 123, "end": 137, "probability": 0.3891, "type": "Product", "normalized_text": "Factory Farming"}, {"start": 268, "end": 272, "probability": 0.4638, "type": "Product", "normalized_text": "Apple"}]}, "context_annotations": [{"domain": {"id": "10", "name": "Person", "description": "Named people in the world like Nelson Mandela"}, "entity": {"id": "809105292814270464", "name": "Tim Cook", "description": "Tim Cook"}}, {"domain": {"id": "45", "name": "Brand Vertical", "description": "Top level entities that describe a Brands industry"}, "entity": {"id": "781972125171060736", "name": "Auto"}}, {"domain": {"id": "46", "name": "Brand Category", "description": "Categories within Brand Verticals that narrow down the scope of Brands"}, "entity": {"id": "781972125179518977", "name": "Auto Manufacturer"}}, {"domain": {"id": "47", "name": "Brand", "description": "Brands and Companies"}, "entity": {"id": "10044199219", "name": "Tesla Motors"}}, {"domain": {"id": "65", "name": "Interests and Hobbies Vertical", "description": "Top level interests and hobbies groupings, like Food or Travel"}, "entity": {"id": "847528391163092993", "name": "Automotive", "description": "Car culture"}}, {"domain": {"id": "66", "name": "Interests and Hobbies Category", "description": "A grouping of interests and hobbies entities, like Novelty Food or Destinations"}, "entity": {"id": "847528576551337984", "name": "Hybrid and electric vehicles", "description": "Hybrid and electric vehicles"}}, {"domain": {"id": "66", "name": "Interests and Hobbies Category", "description": "A grouping of interests and hobbies entities, like Novelty Food or Destinations"}, "entity": {"id": "847528646185070592", "name": "Luxury Cars", "description": "Luxury"}}], "in_reply_to_user_id": "1636590253", "id": "1505361172295417862", "referenced_tweets": [{"type": "replied_to", "id": "1502469915239862273", "context_annotations": [{"domain": {"id": "47", "name": "Brand", "description": "Brands and Companies"}, "entity": {"id": "10026364281", "name": "Apple"}}, {"domain": {"id": "10", "name": "Person", "description": "Named people in the world like Nelson Mandela"}, "entity": {"id": "809105292814270464", "name": "Tim Cook", "description": "Tim Cook"}}], "entities": {"annotations": [{"start": 21, "end": 29, "probability": 0.991, "type": "Place", "normalized_text": "Australia"}, {"start": 144, "end": 148, "probability": 0.9357, "type": "Organization", "normal ...
# {"entities": {"mentions": [{"start": 3, "end": 18, "username": "onthomas_tweet", "id": "460797854", "profile_image_url": "https://pbs.twimg.com/profile_images/1412223411124785155/tCbB7w-__normal.jpg", "entities": {"url": {"urls": [{"start": 0, "end": 23, "url": "https://t.co/LfNTIz5O4g", "expanded_url": "https://www.ted.com/talks/thomas_girard_how_to_feel_at_home_in_the_airport?language=en", "display_url": "ted.com/talks/thomas_g\u2026"}]}}, "description": "\ud83d\udc4c TEDx Speaker | \u2708\ufe0f Emerging Scholar", "created_at": "2012-01-11T04:04:34.000Z", "verified": false, "public_metrics": {"followers_count": 3568, "following_count": 4851, "tweet_count": 6609, "listed_count": 35}, "name": "Thomas K Girard", "location": "Vancouver, Canada", "protected": false, "url": "https://t.co/LfNTIz5O4g", "pinned_tweet_id": "1446899463319031809"}], "hashtags": [{"start": 62, "end": 70, "tag": "climate"}, {"start": 71, "end": 85, "tag": "climatechange"}, {"start": 86, "end": 98, "tag": "environment"}, {"start": 99, "end": 106, "tag": "nature"}, {"start": 107, "end": 121, "tag": "globalwarming"}, {"start": 122, "end": 136, "tag": "climatecrisis"}]}, "context_annotations": [{"domain": {"id": "67", "name": "Interests and Hobbies", "description": "Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks"}, "entity": {"id": "1103294729079349250", "name": "Nature", "description": "Nature"}}], "id": "1505359831435075585", "referenced_tweets": [{"type": "retweeted", "id": "1505357700393160707", "context_annotations": [{"domain": {"id": "67", "name": "Interests and Hobbies", "description": "Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks"}, "entity": {"id": "1103294729079349250", "name": "Nature", "description": "Nature"}}], "entities": {"hashtags": [{"start": 42, "end": 50, "tag": "climate"}, {"start": 51, "end": 65, "tag": "climatechange"}, {"start": 66, "end": 78, "tag": "environment"}, {"start": 79, "end": 86, "tag": "nature"}, {"start": 87, "end": 101, "tag": "globalwarming"}, {"start": 102, "end": 116, "tag": "climatecrisis"}, {"start": 117, "end": 131, "tag": "climateaction"}, {"start": 132, "end": 138, "tag": "earth"}, {"start": 139, "end": 154, "tag": "sustainability"}, {"start": 155, "end": 169, "tag": "savetheplanet"}, {"start": 170, "end": 190, "tag": "climatechangeisreal"}, {"start": 191, "end": 205, "tag": "climatestrike"}, {"start": 206, "end": 223, "tag": "climateemergency"}, {"start": 224, "end": 239, "tag": "climatejustice"}, {"start": 240, "end": 252, "tag": "sustainable"}, {"start": 253, "end": 265, "tag": "ecofriendly"}], "urls": [{"start": 266, "end": 289, "url": "https://t.co/zMM3tJdwf4", "expanded_url": "https://twitter.com/onthomas_tweet/status/1505357700393160707/photo/1", "display_url": "pic.twitter.com/zMM3tJdwf4"}]}, "source": "Twitter for iPhone", "author_id": "460797854", "lang": "en", "reply_settings": "everyone", "created_at": "2022-03-20T01:36:58.000Z", "conversation_id": "1505357700393160707", "public_metrics": {"retweet_count": 4, "reply_count": 0, "like_count": 0, "quote_count": 0}, "attachments": {"media_keys": ["3_1505357696874164224"], "media": [{"width": 1200, "type": "photo", "media_key": "3_1505357696874164224", "url": "https://pbs.twimg.com/media/FOQa2X4VsAA_NNd.jpg", "height": 600}]}, "possibly_sensitive": false, "text": "Excited to guest podcast on Friday!\n.\n.\n.\n#climate #climatechange #environment #nature #globalwarming #climatecrisis #climateaction #earth #sustainability #savetheplanet #climatechangeisreal #climatestrike #climateemergency #climatejustice #sustainable #ecofriendly https://t.co/zMM3tJdwf4", "author": {"profile_image_url": "https://pbs.twimg.com/profile_images/1412223411124785155/tCbB7w-__normal.jpg", "username": "onthomas_tweet", "entities": {"url": {"urls": [{"start": 0, "end": 23, "url": "https://t.co/LfNTIz5O4g", "expanded_url": "https://www.ted.com/talks/thomas ...
# {"entities": {"mentions": [{"start": 3, "end": 18, "username": "onthomas_tweet", "id": "460797854", "profile_image_url": "https://pbs.twimg.com/profile_images/1412223411124785155/tCbB7w-__normal.jpg", "entities": {"url": {"urls": [{"start": 0, "end": 23, "url": "https://t.co/LfNTIz5O4g", "expanded_url": "https://www.ted.com/talks/thomas_girard_how_to_feel_at_home_in_the_airport?language=en", "display_url": "ted.com/talks/thomas_g\u2026"}]}}, "description": "\ud83d\udc4c TEDx Speaker | \u2708\ufe0f Emerging Scholar", "created_at": "2012-01-11T04:04:34.000Z", "verified": false, "public_metrics": {"followers_count": 3568, "following_count": 4851, "tweet_count": 6609, "listed_count": 35}, "name": "Thomas K Girard", "location": "Vancouver, Canada", "protected": false, "url": "https://t.co/LfNTIz5O4g", "pinned_tweet_id": "1446899463319031809"}], "hashtags": [{"start": 62, "end": 70, "tag": "climate"}, {"start": 71, "end": 85, "tag": "climatechange"}, {"start": 86, "end": 98, "tag": "environment"}, {"start": 99, "end": 106, "tag": "nature"}, {"start": 107, "end": 121, "tag": "globalwarming"}, {"start": 122, "end": 136, "tag": "climatecrisis"}]}, "context_annotations": [{"domain": {"id": "67", "name": "Interests and Hobbies", "description": "Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks"}, "entity": {"id": "1103294729079349250", "name": "Nature", "description": "Nature"}}], "id": "1505357865598390276", "referenced_tweets": [{"type": "retweeted", "id": "1505357700393160707", "context_annotations": [{"domain": {"id": "67", "name": "Interests and Hobbies", "description": "Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks"}, "entity": {"id": "1103294729079349250", "name": "Nature", "description": "Nature"}}], "entities": {"hashtags": [{"start": 42, "end": 50, "tag": "climate"}, {"start": 51, "end": 65, "tag": "climatechange"}, {"start": 66, "end": 78, "tag": "environment"}, {"start": 79, "end": 86, "tag": "nature"}, {"start": 87, "end": 101, "tag": "globalwarming"}, {"start": 102, "end": 116, "tag": "climatecrisis"}, {"start": 117, "end": 131, "tag": "climateaction"}, {"start": 132, "end": 138, "tag": "earth"}, {"start": 139, "end": 154, "tag": "sustainability"}, {"start": 155, "end": 169, "tag": "savetheplanet"}, {"start": 170, "end": 190, "tag": "climatechangeisreal"}, {"start": 191, "end": 205, "tag": "climatestrike"}, {"start": 206, "end": 223, "tag": "climateemergency"}, {"start": 224, "end": 239, "tag": "climatejustice"}, {"start": 240, "end": 252, "tag": "sustainable"}, {"start": 253, "end": 265, "tag": "ecofriendly"}], "urls": [{"start": 266, "end": 289, "url": "https://t.co/zMM3tJdwf4", "expanded_url": "https://twitter.com/onthomas_tweet/status/1505357700393160707/photo/1", "display_url": "pic.twitter.com/zMM3tJdwf4"}]}, "source": "Twitter for iPhone", "author_id": "460797854", "lang": "en", "reply_settings": "everyone", "created_at": "2022-03-20T01:36:58.000Z", "conversation_id": "1505357700393160707", "public_metrics": {"retweet_count": 4, "reply_count": 0, "like_count": 0, "quote_count": 0}, "attachments": {"media_keys": ["3_1505357696874164224"], "media": [{"width": 1200, "type": "photo", "media_key": "3_1505357696874164224", "url": "https://pbs.twimg.com/media/FOQa2X4VsAA_NNd.jpg", "height": 600}]}, "possibly_sensitive": false, "text": "Excited to guest podcast on Friday!\n.\n.\n.\n#climate #climatechange #environment #nature #globalwarming #climatecrisis #climateaction #earth #sustainability #savetheplanet #climatechangeisreal #climatestrike #climateemergency #climatejustice #sustainable #ecofriendly https://t.co/zMM3tJdwf4", "author": {"profile_image_url": "https://pbs.twimg.com/profile_images/1412223411124785155/tCbB7w-__normal.jpg", "username": "onthomas_tweet", "entities": {"url": {"urls": [{"start": 0, "end": 23, "url": "https://t.co/LfNTIz5O4g", "expanded_url": "https://www.ted.com/talks/thomas ...
# {"context_annotations": [{"domain": {"id": "67", "name": "Interests and Hobbies", "description": "Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks"}, "entity": {"id": "1103294729079349250", "name": "Nature", "description": "Nature"}}], "entities": {"hashtags": [{"start": 42, "end": 50, "tag": "climate"}, {"start": 51, "end": 65, "tag": "climatechange"}, {"start": 66, "end": 78, "tag": "environment"}, {"start": 79, "end": 86, "tag": "nature"}, {"start": 87, "end": 101, "tag": "globalwarming"}, {"start": 102, "end": 116, "tag": "climatecrisis"}, {"start": 117, "end": 131, "tag": "climateaction"}, {"start": 132, "end": 138, "tag": "earth"}, {"start": 139, "end": 154, "tag": "sustainability"}, {"start": 155, "end": 169, "tag": "savetheplanet"}, {"start": 170, "end": 190, "tag": "climatechangeisreal"}, {"start": 191, "end": 205, "tag": "climatestrike"}, {"start": 206, "end": 223, "tag": "climateemergency"}, {"start": 224, "end": 239, "tag": "climatejustice"}, {"start": 240, "end": 252, "tag": "sustainable"}, {"start": 253, "end": 265, "tag": "ecofriendly"}], "urls": [{"start": 266, "end": 289, "url": "https://t.co/zMM3tJdwf4", "expanded_url": "https://twitter.com/onthomas_tweet/status/1505357700393160707/photo/1", "display_url": "pic.twitter.com/zMM3tJdwf4"}]}, "id": "1505357700393160707", "source": "Twitter for iPhone", "author_id": "460797854", "lang": "en", "reply_settings": "everyone", "created_at": "2022-03-20T01:36:58.000Z", "conversation_id": "1505357700393160707", "public_metrics": {"retweet_count": 4, "reply_count": 0, "like_count": 0, "quote_count": 0}, "attachments": {"media_keys": ["3_1505357696874164224"], "media": [{"width": 1200, "type": "photo", "media_key": "3_1505357696874164224", "url": "https://pbs.twimg.com/media/FOQa2X4VsAA_NNd.jpg", "height": 600}]}, "possibly_sensitive": false, "text": "Excited to guest podcast on Friday!\n.\n.\n.\n#climate #climatechange #environment #nature #globalwarming #climatecrisis #climateaction #earth #sustainability #savetheplanet #climatechangeisreal #climatestrike #climateemergency #climatejustice #sustainable #ecofriendly https://t.co/zMM3tJdwf4", "author": {"profile_image_url": "https://pbs.twimg.com/profile_images/1412223411124785155/tCbB7w-__normal.jpg", "username": "onthomas_tweet", "entities": {"url": {"urls": [{"start": 0, "end": 23, "url": "https://t.co/LfNTIz5O4g", "expanded_url": "https://www.ted.com/talks/thomas_girard_how_to_feel_at_home_in_the_airport?language=en", "display_url": "ted.com/talks/thomas_g\u2026"}]}}, "description": "\ud83d\udc4c TEDx Speaker | \u2708\ufe0f Emerging Scholar", "created_at": "2012-01-11T04:04:34.000Z", "verified": false, "public_metrics": {"followers_count": 3568, "following_count": 4851, "tweet_count": 6609, "listed_count": 35}, "name": "Thomas K Girard", "location": "Vancouver, Canada", "protected": false, "url": "https://t.co/LfNTIz5O4g", "pinned_tweet_id": "1446899463319031809", "id": "460797854"}, "__twarc": {"url": "https://api.twitter.com/2/tweets/search/all?expansions=author_id%2Cin_reply_to_user_id%2Creferenced_tweets.id%2Creferenced_tweets.id.author_id%2Centities.mentions.username%2Cattachments.poll_ids%2Cattachments.media_keys%2Cgeo.place_id&tweet.fields=attachments%2Cauthor_id%2Ccontext_annotations%2Cconversation_id%2Ccreated_at%2Centities%2Cgeo%2Cid%2Cin_reply_to_user_id%2Clang%2Cpublic_metrics%2Ctext%2Cpossibly_sensitive%2Creferenced_tweets%2Creply_settings%2Csource%2Cwithheld&user.fields=created_at%2Cdescription%2Centities%2Cid%2Clocation%2Cname%2Cpinned_tweet_id%2Cprofile_image_url%2Cprotected%2Cpublic_metrics%2Curl%2Cusername%2Cverified%2Cwithheld&media.fields=alt_text%2Cduration_ms%2Cheight%2Cmedia_key%2Cpreview_image_url%2Ctype%2Curl%2Cwidth%2Cpublic_metrics&poll.fields=duration_minutes%2Cend_datetime%2Cid%2Coptions%2Cvoting_status&place.fields=contained_within%2Ccountry%2Ccountry_code%2Cfull_name%2Cgeo%2Cid%2Cname%2Cplace_type&start_time=2022-03-20T01%3A00%3 ...
# {"context_annotations": [{"domain": {"id": "65", "name": "Interests and Hobbies Vertical", "description": "Top level interests and hobbies groupings, like Food or Travel"}, "entity": {"id": "781974596148793345", "name": "Business & finance"}}, {"domain": {"id": "65", "name": "Interests and Hobbies Vertical", "description": "Top level interests and hobbies groupings, like Food or Travel"}, "entity": {"id": "781974596148793345", "name": "Business & finance"}}, {"domain": {"id": "66", "name": "Interests and Hobbies Category", "description": "A grouping of interests and hobbies entities, like Novelty Food or Destinations"}, "entity": {"id": "847888632711061504", "name": "Personal finance", "description": "Personal finance"}}, {"domain": {"id": "67", "name": "Interests and Hobbies", "description": "Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks"}, "entity": {"id": "847894794080722944", "name": "Retirement planning", "description": "Retirement planning"}}, {"domain": {"id": "67", "name": "Interests and Hobbies", "description": "Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks"}, "entity": {"id": "1037075567227494400", "name": "Saving and finance", "description": "Saving and Finance"}}, {"domain": {"id": "86", "name": "Movie", "description": "A film like Rogue One: A Star Wars Story"}, "entity": {"id": "1461347524858441736", "name": "Don't Look Up", "description": "Produced by Hyperobject Industries and Bluegrass Films, the film is set to receive a limited theatrical release on December 10, 2021, prior to streaming on Netflix on December 24, 2021."}}, {"domain": {"id": "87", "name": "Movie Genre", "description": "A movie genre like Action"}, "entity": {"id": "856977093191647233", "name": "Sci-fi & fantasy films", "description": "Sci-fi and fantasy"}}], "entities": {"hashtags": [{"start": 82, "end": 93, "tag": "VoteWisely"}, {"start": 95, "end": 113, "tag": "UseYourVoteWisely"}, {"start": 114, "end": 119, "tag": "Vote"}, {"start": 120, "end": 131, "tag": "DontLookUp"}, {"start": 132, "end": 147, "tag": "EnoughIsEnough"}, {"start": 148, "end": 162, "tag": "GlobalWarming"}, {"start": 163, "end": 180, "tag": "ClimateEmergency"}, {"start": 181, "end": 189, "tag": "Climate"}, {"start": 190, "end": 204, "tag": "ClimateCrisis"}, {"start": 205, "end": 219, "tag": "ClimateChange"}, {"start": 220, "end": 234, "tag": "ClimateAction"}, {"start": 235, "end": 254, "tag": "ClimateCatastrophe"}, {"start": 255, "end": 262, "tag": "auspol"}], "urls": [{"start": 263, "end": 286, "url": "https://t.co/RWkUb8qSjL", "expanded_url": "https://twitter.com/anniekia/status/1505130808482295813", "display_url": "twitter.com/anniekia/statu\u2026"}]}, "id": "1505355399889043464", "referenced_tweets": [{"type": "quoted", "id": "1505130808482295813", "entities": {"hashtags": [{"start": 206, "end": 224, "tag": "ClimateDisruption"}], "urls": [{"start": 229, "end": 252, "url": "https://t.co/SLFum4Lk2k", "expanded_url": "https://twitter.com/AnnieKia/status/1505130808482295813/photo/1", "display_url": "pic.twitter.com/SLFum4Lk2k"}, {"start": 229, "end": 252, "url": "https://t.co/SLFum4Lk2k", "expanded_url": "https://twitter.com/AnnieKia/status/1505130808482295813/photo/1", "display_url": "pic.twitter.com/SLFum4Lk2k"}, {"start": 229, "end": 252, "url": "https://t.co/SLFum4Lk2k", "expanded_url": "https://twitter.com/AnnieKia/status/1505130808482295813/photo/1", "display_url": "pic.twitter.com/SLFum4Lk2k"}]}, "source": "Twitter for iPad", "author_id": "989830747", "lang": "en", "reply_settings": "everyone", "created_at": "2022-03-19T10:35:23.000Z", "conversation_id": "1505130808482295813", "public_metrics": {"retweet_count": 685, "reply_count": 42, "like_count": 1237, "quote_count": 112}, "attachments": {"media_keys": ["3_1505130783152873472", "3_1505130783161282563", "3_1505130783165456384"], "media": [{}, {}, {}]}, "possibly_sensitive": false, "text" ...
# {"entities": {"hashtags": [{"start": 135, "end": 149, "tag": "climatechange"}, {"start": 150, "end": 164, "tag": "globalwarming"}], "annotations": [{"start": 100, "end": 113, "probability": 0.9333, "type": "Place", "normalized_text": "Balmoral Beach"}, {"start": 116, "end": 121, "probability": 0.6419, "type": "Place", "normalized_text": "Sydney"}, {"start": 124, "end": 132, "probability": 0.5254, "type": "Place", "normalized_text": "Australia"}], "urls": [{"start": 165, "end": 188, "url": "https://t.co/wFnjjpDaEw", "expanded_url": "https://www.instagram.com/p/CbTnt-QhHSK/?utm_medium=twitter", "display_url": "instagram.com/p/CbTnt-QhHSK/\u2026", "images": [{"url": "https://pbs.twimg.com/news_img/1505349861499367425/9FV83Dt4?format=jpg&name=orig", "width": 601, "height": 600}, {"url": "https://pbs.twimg.com/news_img/1505349861499367425/9FV83Dt4?format=jpg&name=150x150", "width": 150, "height": 150}], "status": 200, "title": "Ken Howard (@ken.howard1) \u2022 Instagram photo", "description": "0 Likes, 0 Comments - Ken Howard (@ken.howard1) on Instagram: \u201c114 years later, yes there definitely is global warming! Ha ha ha ha... look closely at the rock...\u2026\u201d", "unwound_url": "https://www.instagram.com/p/CbTnt-QhHSK/?utm_medium=twitter"}]}, "id": "1505349857623814145", "source": "Instagram", "author_id": "57484464", "lang": "en", "reply_settings": "everyone", "created_at": "2022-03-20T01:05:48.000Z", "conversation_id": "1505349857623814145", "public_metrics": {"retweet_count": 0, "reply_count": 0, "like_count": 0, "quote_count": 0}, "possibly_sensitive": false, "text": "114 years later, yes there definitely is global warming! Ha ha ha ha... look closely at the rock... Balmoral Beach, Sydney, Australia. #climatechange #globalwarming https://t.co/wFnjjpDaEw", "author": {"profile_image_url": "https://pbs.twimg.com/profile_images/586037124824072192/PSw9zt4p_normal.jpg", "username": "ken_howard1", "entities": {"url": {"urls": [{"start": 0, "end": 23, "url": "https://t.co/ufLucLjwhW", "expanded_url": "http://www.facebook.com/kenhowarddesigner", "display_url": "facebook.com/kenhowarddesig\u2026"}]}}, "description": "Toy, Game, New Product Developer for TV shows, Inventors, Toy companies worldwide... over 1,500 titles developed, millions manufactured. Owner of OneMusicAfrica", "created_at": "2009-07-16T23:41:24.000Z", "verified": false, "public_metrics": {"followers_count": 687, "following_count": 2008, "tweet_count": 2245, "listed_count": 7}, "name": "Ken Howard", "location": "Sydney, Australia, USA & HK", "protected": false, "url": "https://t.co/ufLucLjwhW", "id": "57484464"}, "__twarc": {"url": "https://api.twitter.com/2/tweets/search/all?expansions=author_id%2Cin_reply_to_user_id%2Creferenced_tweets.id%2Creferenced_tweets.id.author_id%2Centities.mentions.username%2Cattachments.poll_ids%2Cattachments.media_keys%2Cgeo.place_id&tweet.fields=attachments%2Cauthor_id%2Ccontext_annotations%2Cconversation_id%2Ccreated_at%2Centities%2Cgeo%2Cid%2Cin_reply_to_user_id%2Clang%2Cpublic_metrics%2Ctext%2Cpossibly_sensitive%2Creferenced_tweets%2Creply_settings%2Csource%2Cwithheld&user.fields=created_at%2Cdescription%2Centities%2Cid%2Clocation%2Cname%2Cpinned_tweet_id%2Cprofile_image_url%2Cprotected%2Cpublic_metrics%2Curl%2Cusername%2Cverified%2Cwithheld&media.fields=alt_text%2Cduration_ms%2Cheight%2Cmedia_key%2Cpreview_image_url%2Ctype%2Curl%2Cwidth%2Cpublic_metrics&poll.fields=duration_minutes%2Cend_datetime%2Cid%2Coptions%2Cvoting_status&place.fields=contained_within%2Ccountry%2Ccountry_code%2Cfull_name%2Cgeo%2Cid%2Cname%2Cplace_type&start_time=2022-03-20T01%3A00%3A00%2B00%3A00&end_time=2022-03-20T02%3A00%3A00%2B00%3A00&query=%28%23climatechange%2C+%23globalwarming%29+OR+%28climate+change%29+-is%3Aretweet+lang%3Aen+place%3ABoston&max_results=100", "version": "2.9.2", "retrieved_at": "2022-03-21T13:30:31+00:00"}}

# %%
from twarc import Twarc2, expansions
import datetime
import json
import csv

# Replace your bearer token below. You may use below code if you do not have a twitter developer account yet
client = Twarc2(bearer_token="AAAAAAAAAAAAAAAAAAAAAGSXZQEAAAAAk6YVv7DVW74eDZZ5u698Inv4QXc%3DCpTroI60R3imjzDPgwoEr6CRWIWjxoqSR1jOTQJtl0to45EHce")


def main():
    # Specify the start time in UTC for the time period you want replies from
    start_time = datetime.datetime(2022, 3, 20, 0, 0, 0, 0, datetime.timezone.utc)

    # Specify the end time in UTC for the time period you want Tweets from
    end_time = datetime.datetime(2022, 3, 21, 0, 0, 0, 0, datetime.timezone.utc)

    # This is where we specify our query as discussed in module 5.
    query = "(#climatechange, #globalwarming) OR (climate change) -is:retweet lang:en place:Boston"

    # Name and path of the file where you want the Tweets written to
    file_name = 'climateChange_20220320.csv'

    # The search_all method call the full-archive search endpoint to get Tweets based on the query, start and end times
    search_results = client.search_all(query=query, start_time=start_time, end_time=end_time, max_results=100)

    # Twarc returns all Tweets for the criteria set above, so we page through the results
    for page in search_results:
        # The Twitter API v2 returns the Tweet information and the user, media etc.  separately
        # so we use expansions.flatten to get all the information in a single JSON
        result = expansions.flatten(page)
        # We will open the file and append one JSON object per new line
        with open(file_name, 'a', newline='', encoding="utf8") as filehandle:
            writer = csv.writer(filehandle, delimiter='|')
            for tweet in result:
                d={}
                oneTweet=json.dumps(tweet)
                onetweet=json.loads(oneTweet)
                d['tweet_id'] = onetweet['id']
                d['created_at'] = onetweet['created_at']
                d['user_name']=onetweet['author']['username']
                d['text']=onetweet['text'].replace('\n', ' ').replace('\r', '')
                #print(d)
                writer.writerow(list(d.values()))

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6512/91022402.py in <module>
# ----> 1 from twarc import Twarc2, expansions
#       2 import datetime
#       3 import json
#       4 import csv
#       5
#
# ModuleNotFoundError: No module named 'twarc'

# %%
import pandas as pd

climate=pd.read_csv('climateChange_20220320.csv',sep="|", header=None)

cols=['tweet_id', 'created_at', 'user_name', 'text'] # define columns header

climate.columns=cols

# %%
climate.head()
# Out:
#               tweet_id                created_at       user_name  \
# 0  1505694588715028481  2022-03-20T23:55:39.000Z   africaupdates
# 1  1505690734913290240  2022-03-20T23:40:20.000Z  ChristineMilne
# 2  1505690358088355841  2022-03-20T23:38:50.000Z     ig_NeverDie
# 3  1505690101619253254  2022-03-20T23:37:49.000Z        JRenee4V
# 4  1505689908068990977  2022-03-20T23:37:03.000Z     gridpointwx
#
#                                                 text
# 0  RT @jmollel: A new study shows that the future...
# 1  RT @ProfStrachan: Nice explainer @FT @ftenergy...
# 2  you can't stop nature, nature can stop you  #L...
# 3  RT @TamsManke: #ClimateChange #GlobalWarming #...
# 4  Hibernating bears adapt to changing #CLIMATE h...

# %%
climate['text'][0:10]
# Out:
# 0        RT @jmollel: A new study shows that the future of Kenya’s coffee industry is threatened by #climatechange. #globalwarming may shrink the la…
# 1         RT @ProfStrachan: Nice explainer @FT @ftenergy  The Race To Curb #GlobalWarming  "One pressing question is how much #ClimateChange will be…
# 2               you can't stop nature, nature can stop you  #Leaf #Plant #Nature #Globalwarming #Globalwarming #Climatechange https://t.co/F5jp19iNMC
# 3                                                              RT @TamsManke: #ClimateChange #GlobalWarming #TheGreatDelusion https://t.co/SD2gnbThTq
# 4                                                 Hibernating bears adapt to changing #CLIMATE https://t.co/BZEq9NtAZQ  #GlobalWarming #climatechange
# 5                                            Hibernating bears adapt to changing #CLIMATE https://t.co/CrZkXAIH49 #GPWX #GlobalWarming #climatechange
# 6    RT @HelpThePlaNFT: Wanna have a sneak peek?🐻❄️  In the mean time:  ⭐️ 5 WL GIVEAWAY ⭐️  🌱 Follow @HelpThePlaNFT 🌸 Like &amp; RT 🌍 Tag 3 friends…
# 7                                                              RT @TamsManke: #ClimateChange #GlobalWarming #TheGreatDelusion https://t.co/SD2gnbThTq
# 8                                                              RT @TamsManke: #ClimateChange #GlobalWarming #TheGreatDelusion https://t.co/SD2gnbThTq
# 9        RT @mncbags: SOMETHING IS UP IN WITH EARTH’S NORTH AND SOUTH POLES. https://t.co/txnAxrO64l #globalwarming #climatechange #environment #sav…
# Name: text, dtype: object

# %% [markdown]
# ## [Sentiment Analysis](https://pypi.org/project/vaderSentiment/)

# %%
! pip install vaderSentiment==3.3.2
# Out:
# Collecting vaderSentiment==3.3.2
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from vaderSentiment==3.3.2) (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests->vaderSentiment==3.3.2) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->vaderSentiment==3.3.2) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->vaderSentiment==3.3.2) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->vaderSentiment==3.3.2) (2021.10.8)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -equests (c:\programdata\anaconda3\lib\site-packages)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

sentiment = []
analyzer = SentimentIntensityAnalyzer()

for index, row in climate.iterrows():
    tweet = str(row['text'])
    vs = analyzer.polarity_scores(tweet)
    sentiment.append(vs)
    
climate['VaderSentiment'] = sentiment

# %%
climate.head(10)
# Out:
#               tweet_id                created_at        user_name  \
# 0  1505694588715028481  2022-03-20T23:55:39.000Z    africaupdates
# 1  1505690734913290240  2022-03-20T23:40:20.000Z   ChristineMilne
# 2  1505690358088355841  2022-03-20T23:38:50.000Z      ig_NeverDie
# 3  1505690101619253254  2022-03-20T23:37:49.000Z         JRenee4V
# 4  1505689908068990977  2022-03-20T23:37:03.000Z      gridpointwx
# 5  1505689839190122497  2022-03-20T23:36:46.000Z        TimMelino
# 6  1505688591204499459  2022-03-20T23:31:49.000Z           kchu1x
# 7  1505688571818115074  2022-03-20T23:31:44.000Z    RoseRockwell8
# 8  1505687471077556224  2022-03-20T23:27:22.000Z      dj_ramquist
# 9  1505684702346489856  2022-03-20T23:16:21.000Z  RajKapo42077508
#
#                                                                                                                                                text  \
# 0      RT @jmollel: A new study shows that the future of Kenya’s coffee industry is threatened by #climatechange. #globalwarming may shrink the la…
# 1       RT @ProfStrachan: Nice explainer @FT @ftenergy  The Race To Curb #GlobalWarming  "One pressing question is how much #ClimateChange will be…
# 2             you can't stop nature, nature can stop you  #Leaf #Plant #Nature #Globalwarming #Globalwarming #Climatechange https://t.co/F5jp19iNMC
# 3                                                            RT @TamsManke: #ClimateChange #GlobalWarming #TheGreatDelusion https://t.co/SD2gnbThTq
# 4                                               Hibernating bears adapt to changing #CLIMATE https://t.co/BZEq9NtAZQ  #GlobalWarming #climatechange
# 5                                          Hibernating bears adapt to changing #CLIMATE https://t.co/CrZkXAIH49 #GPWX #GlobalWarming #climatechange
# 6  RT @HelpThePlaNFT: Wanna have a sneak peek?🐻❄️  In the mean time:  ⭐️ 5 WL GIVEAWAY ⭐️  🌱 Follow @HelpThePlaNFT 🌸 Like &amp; RT 🌍 Tag 3 friends…
# 7                                                            RT @TamsManke: #ClimateChange #GlobalWarming #TheGreatDelusion https://t.co/SD2gnbThTq
# 8                                                            RT @TamsManke: #ClimateChange #GlobalWarming #TheGreatDelusion https://t.co/SD2gnbThTq
# 9      RT @mncbags: SOMETHING IS UP IN WITH EARTH’S NORTH AND SOUTH POLES. https://t.co/txnAxrO64l #globalwarming #climatechange #environment #sav…
#
#                                                    VaderSentiment
# 0   {'neg': 0.125, 'neu': 0.875, 'pos': 0.0, 'compound': -0.4588}
# 1    {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.4215}
# 2  {'neg': 0.129, 'neu': 0.761, 'pos': 0.11, 'compound': -0.0803}
# 3           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 4           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 5           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 6    {'neg': 0.0, 'neu': 0.928, 'pos': 0.072, 'compound': 0.3612}
# 7           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 8           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 9           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
pd.set_option('display.max_columns', None) # This will make it so all columns appear when printing
pd.options.display.max_colwidth = 300  # This makes it so we can see the entire tweet text.

climate.head(20)
# Out:
#                tweet_id                created_at        user_name  \
# 0   1505694588715028481  2022-03-20T23:55:39.000Z    africaupdates
# 1   1505690734913290240  2022-03-20T23:40:20.000Z   ChristineMilne
# 2   1505690358088355841  2022-03-20T23:38:50.000Z      ig_NeverDie
# 3   1505690101619253254  2022-03-20T23:37:49.000Z         JRenee4V
# 4   1505689908068990977  2022-03-20T23:37:03.000Z      gridpointwx
# 5   1505689839190122497  2022-03-20T23:36:46.000Z        TimMelino
# 6   1505688591204499459  2022-03-20T23:31:49.000Z           kchu1x
# 7   1505688571818115074  2022-03-20T23:31:44.000Z    RoseRockwell8
# 8   1505687471077556224  2022-03-20T23:27:22.000Z      dj_ramquist
# 9   1505684702346489856  2022-03-20T23:16:21.000Z  RajKapo42077508
# 10  1505684566337781764  2022-03-20T23:15:49.000Z  RajKapo42077508
# 11  1505684516136165376  2022-03-20T23:15:37.000Z  RajKapo42077508
# 12  1505684456757248001  2022-03-20T23:15:23.000Z        Eco1stArt
# 13  1505684362330836996  2022-03-20T23:15:00.000Z        Eco1stArt
# 14  1505683832447680515  2022-03-20T23:12:54.000Z     IamtheGreeny
# 15  1505683793629302792  2022-03-20T23:12:45.000Z     IamtheGreeny
# 16  1505683327520493573  2022-03-20T23:10:54.000Z          mncbags
# 17  1505682549397409794  2022-03-20T23:07:48.000Z   imagine_garden
# 18  1505682380274769925  2022-03-20T23:07:08.000Z   imagine_garden
# 19  1505682295713378307  2022-03-20T23:06:48.000Z   imagine_garden
#
#                                                                                                                                                                                                                                                text  \
# 0                                                                                                      RT @jmollel: A new study shows that the future of Kenya’s coffee industry is threatened by #climatechange. #globalwarming may shrink the la…
# 1                                                                                                       RT @ProfStrachan: Nice explainer @FT @ftenergy  The Race To Curb #GlobalWarming  "One pressing question is how much #ClimateChange will be…
# 2                                                                                                             you can't stop nature, nature can stop you  #Leaf #Plant #Nature #Globalwarming #Globalwarming #Climatechange https://t.co/F5jp19iNMC
# 3                                                                                                                                                            RT @TamsManke: #ClimateChange #GlobalWarming #TheGreatDelusion https://t.co/SD2gnbThTq
# 4                                                                                                                                               Hibernating bears adapt to changing #CLIMATE https://t.co/BZEq9NtAZQ  #GlobalWarming #climatechange
# 5                                                                                                                                          Hibernating bears adapt to changing #CLIMATE https://t.co/CrZkXAIH49 #GPWX #GlobalWarming #climatechange
# 6                                                                                                  RT @HelpThePlaNFT: Wanna have a sneak peek?🐻❄️  In the mean time:  ⭐️ 5 WL GIVEAWAY ⭐️  🌱 Follow @HelpThePlaNFT 🌸 Like &amp; RT 🌍 Tag 3 friends…
# 7                                                                                                                                                            RT @TamsManke: #ClimateChange #GlobalWarming #TheGreatDelusion https://t.co/SD2gnbThTq
# 8                                                                                                                                                            RT @TamsManke: #ClimateChange #GlobalWarming #TheGreatDelusion https://t.co/SD2gnbThTq
# 9                                                                                                      RT @mncbags: SOMETHING IS UP IN WITH EARTH’S NORTH AND SOUTH POLES. https://t.co/txnAxrO64l #globalwarming #climatechange #environment #sav…
# 10                                                                                                     RT @bombaybags: Google says it has made a major breakthrough on carbon-free energy. https://t.co/ddbPh3fELO #carbonfootprint #climatechange…
# 11                                                                                                     RT @bombaybags: SOMETHING IS UP IN WITH EARTH’S NORTH AND SOUTH POLES. https://t.co/zdYpJO5ArC #globalwarming #climatechange #environment #…
# 12                                                                                                     RT @mncbags: SOMETHING IS UP IN WITH EARTH’S NORTH AND SOUTH POLES. https://t.co/txnAxrO64l #globalwarming #climatechange #environment #sav…
# 13                                                                                                     RT @bombaybags: SOMETHING IS UP IN WITH EARTH’S NORTH AND SOUTH POLES. https://t.co/zdYpJO5ArC #globalwarming #climatechange #environment #…
# 14                                                                                                     RT @mncbags: SOMETHING IS UP IN WITH EARTH’S NORTH AND SOUTH POLES. https://t.co/txnAxrO64l #globalwarming #climatechange #environment #sav…
# 15                                                                                                     RT @bombaybags: SOMETHING IS UP IN WITH EARTH’S NORTH AND SOUTH POLES. https://t.co/zdYpJO5ArC #globalwarming #climatechange #environment #…
# 16  SOMETHING IS UP IN WITH EARTH’S NORTH AND SOUTH POLES. https://t.co/txnAxrO64l #globalwarming #climatechange #environment #savetheplanet #nature #sustainability #climatecrisis #climate #ecofriendly #earth #climateaction #gogreen #zerowaste
# 17                                                                                                     RT @onthomas_tweet: "Advanced Typography and Design" first class complete! Speaking about it in Paris: https://t.co/c1b5wEjUm9  . . . #clim…
# 18                                                                                                     RT @ConcernedMama21: Now they all have "eco-anxiety"? Like it's a real thing.   No, the Left just made these kids crazy! And some adults wi…
# 19                                                                                                     RT @JoeCUGeek: One fantastic read to convey the essential path to a fossil-free future. #climatechange #globalwarming https://t.co/UyLBSPZT…
#
#                                                     VaderSentiment
# 0    {'neg': 0.125, 'neu': 0.875, 'pos': 0.0, 'compound': -0.4588}
# 1     {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.4215}
# 2   {'neg': 0.129, 'neu': 0.761, 'pos': 0.11, 'compound': -0.0803}
# 3            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 4            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 5            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 6     {'neg': 0.0, 'neu': 0.928, 'pos': 0.072, 'compound': 0.3612}
# 7            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 8            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 9            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 10    {'neg': 0.0, 'neu': 0.877, 'pos': 0.123, 'compound': 0.2732}
# 11           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 12           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 13           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 14           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 15           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 16           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 17    {'neg': 0.0, 'neu': 0.887, 'pos': 0.113, 'compound': 0.3164}
# 18  {'neg': 0.088, 'neu': 0.809, 'pos': 0.103, 'compound': 0.1007}
# 19    {'neg': 0.0, 'neu': 0.816, 'pos': 0.184, 'compound': 0.5574}

# %%
#assign compound to a new column

climate['compound']=climate['VaderSentiment'].apply(pd.Series)['compound']

# %%
climate.head()
# Out:
#               tweet_id                created_at       user_name  \
# 0  1505694588715028481  2022-03-20T23:55:39.000Z   africaupdates
# 1  1505690734913290240  2022-03-20T23:40:20.000Z  ChristineMilne
# 2  1505690358088355841  2022-03-20T23:38:50.000Z     ig_NeverDie
# 3  1505690101619253254  2022-03-20T23:37:49.000Z        JRenee4V
# 4  1505689908068990977  2022-03-20T23:37:03.000Z     gridpointwx
#
#                                                                                                                                            text  \
# 0  RT @jmollel: A new study shows that the future of Kenya’s coffee industry is threatened by #climatechange. #globalwarming may shrink the la…
# 1   RT @ProfStrachan: Nice explainer @FT @ftenergy  The Race To Curb #GlobalWarming  "One pressing question is how much #ClimateChange will be…
# 2         you can't stop nature, nature can stop you  #Leaf #Plant #Nature #Globalwarming #Globalwarming #Climatechange https://t.co/F5jp19iNMC
# 3                                                        RT @TamsManke: #ClimateChange #GlobalWarming #TheGreatDelusion https://t.co/SD2gnbThTq
# 4                                           Hibernating bears adapt to changing #CLIMATE https://t.co/BZEq9NtAZQ  #GlobalWarming #climatechange
#
#                                                    VaderSentiment  compound
# 0   {'neg': 0.125, 'neu': 0.875, 'pos': 0.0, 'compound': -0.4588}   -0.4588
# 1    {'neg': 0.0, 'neu': 0.872, 'pos': 0.128, 'compound': 0.4215}    0.4215
# 2  {'neg': 0.129, 'neu': 0.761, 'pos': 0.11, 'compound': -0.0803}   -0.0803
# 3           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}    0.0000
# 4           {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}    0.0000

# %%
climate['compound'].mean()
# Out:
# -0.04341620294599016

# %%
climate['compound'].describe()
# Out:
# count    611.000000
# mean      -0.043416
# std        0.426568
# min       -0.951600
# 25%       -0.296000
# 50%        0.000000
# 75%        0.361200
# max        0.941300
# Name: compound, dtype: float64

# %%
def sentiment_classify(score)
    if score>0:
        return "Positive"
    elif score<0:
        return "Negative"
    else:
        return "Neutral"
# Out:
#   File "C:\Users\ttrego\AppData\Local\Temp/ipykernel_6512/2034772484.py", line 1
#     def sentiment_classify(score)
#                                  ^
# SyntaxError: invalid syntax

# %%
climate['sentiment'].value_counts()
